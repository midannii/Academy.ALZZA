# %%
# %run mlp_model.ipynb
# %run dataset_chap123.ipynb
# %run dataset_flowers.ipynb
# Out:
# /home/midan/study

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.177, accuracy=0.733/0.711 (0/0 secs)
#     Epoch 4: cost=7.434, accuracy=0.743/0.694 (0/0 secs)
#     Epoch 6: cost=7.280, accuracy=0.746/0.737 (0/0 secs)
#     Epoch 8: cost=7.159, accuracy=0.747/0.725 (0/0 secs)
#     Epoch 10: cost=7.063, accuracy=0.751/0.746 (0/0 secs)
# Model abalone_model train ended in 0 secs:
# Model abalone_model test report: accuracy = 0.726, (0 secs)
#
# Model abalone_model Visualization
# [0.00,0.00,1.00,0.70,0.53,0.17,1.56,0.61,0.39,0.44] => 추정 13.0 : 정답 10.0
# [0.00,1.00,0.00,0.46,0.38,0.12,0.48,0.22,0.10,0.17] => 추정  8.7 : 정답  7.0
# [0.00,0.00,1.00,0.58,0.45,0.14,1.14,0.56,0.22,0.29] => 추정 11.2 : 정답  8.0

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [4])
pm.exec_all()
# Out:
# Model pulsar_model train ended in 2 secs:
# Model pulsar_model test report: accuracy = 0.968, (0 secs)
#
# Model pulsar_model Visualization
# [121.8, 48.0,  0.2,...] => 추정 별(확률 0.01) : 정답 별 => O
# [143.5, 46.0, -0.3,...] => 추정 별(확률 0.00) : 정답 별 => O
# [170.4, 40.9, -0.9,...] => 추정 별(확률 0.01) : 정답 별 => O

# %%
pm.visualize(5)
# Out:
# Model pulsar_model Visualization
# [ 26.8, 27.4,  6.1,...] => 추정 펄서(확률 1.00) : 정답 펄서 => O
# [143.5, 40.5, -0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# [ 99.0, 44.0,  0.4,...] => 추정 별(확률 0.02) : 정답 별 => O
# [134.6, 50.6,  0.0,...] => 추정 별(확률 0.00) : 정답 별 => O
# [130.0, 53.9,  0.4,...] => 추정 별(확률 0.09) : 정답 별 => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.848, accuracy=0.352/0.299 (1/1 secs)
#     Epoch 20: cost=1.784, accuracy=0.352/0.299 (0/1 secs)
#     Epoch 30: cost=1.744, accuracy=0.352/0.299 (0/1 secs)
#     Epoch 40: cost=1.720, accuracy=0.352/0.299 (1/2 secs)
#     Epoch 50: cost=1.705, accuracy=0.352/0.299 (0/2 secs)
# Model steel_model train ended in 2 secs:
# Model steel_model test report: accuracy = 0.337, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 9,10,17, 8, 7,18,30] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 9,10,17, 8, 7,18,30] => 추정 Other_Faults : 정답 Dirtiness => X
# 추정확률분포 [ 9,10,17, 8, 7,18,30] => 추정 Other_Faults : 정답 Other_Faults => O

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [4])
psm.exec_all()
# Out:
# Model pulsar_select_model train ended in 2 secs:
# Model pulsar_select_model test report: accuracy = 0.968, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [58,42] => 추정 별 : 정답 펄서 => X
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [99, 1] => 추정 별 : 정답 별 => O

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.772, accuracy=0.247/0.200 (2/2 secs)
#     Epoch 4: cost=1.751, accuracy=0.247/0.290 (2/4 secs)
#     Epoch 6: cost=1.735, accuracy=0.247/0.220 (2/6 secs)
#     Epoch 8: cost=1.722, accuracy=0.247/0.250 (2/8 secs)
#     Epoch 10: cost=1.710, accuracy=0.247/0.230 (2/10 secs)
# Model flowers_model_1 train ended in 10 secs:
# Model flowers_model_1 test report: accuracy = 0.233, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 daisy => X

# %%
fm2 = MlpModel('flowers_model_2', fd, [30, 10])
fm2.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.773, accuracy=0.246/0.280 (2/2 secs)
#     Epoch 4: cost=1.753, accuracy=0.246/0.220 (2/4 secs)
#     Epoch 6: cost=1.737, accuracy=0.246/0.300 (2/6 secs)
#     Epoch 8: cost=1.723, accuracy=0.246/0.290 (1/7 secs)
#     Epoch 10: cost=1.712, accuracy=0.246/0.210 (2/9 secs)
# Model flowers_model_2 train ended in 9 secs:
# Model flowers_model_2 test report: accuracy = 0.233, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 dandelion => O
